# %%
class MyClass:
  x = 5

# %%
p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

print(p1.x)
print(p2.x)
print(p3)
# Out:
# 5
# 5
# ...

# %% [markdown]
# Classe definition can not be empty so

# %%
class Person:
  pass

# %%
test_person = Person()
print(test_person)

# %%
class Person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name}")

# %%
test_person = Person("André",22)
test_person.greet()
# Out:
# Hello, my name is André

# %% [markdown]
# As it´s possible to see in here we can still add info to an object, creating an atibutte

# %%
class Person:
  pass

p1 = Person()
p1.name = "Tobias"
p1.age = 25

print(p1.name)
print(p1.age)
# Out:
# Tobias
# 25

# %% [markdown]
# set default values it´s a great addition as well

# %%
class Person:
    def __init__(self,name,age=18):
        self.name=name
        self.age = age

p1=Person("andré")
print(p1.age)
# Out:
# 18

# %%
class Person:
  def __init__(self, name, age, city, country):
    self.name = name
    self.age = age
    self.city = city
    self.country = country

p1 = Person("Linus", 30, "Oslo","Norway")

print(p1.name)
print(p1.age)
print(p1.city)
print(p1.country)
# Out:
# Linus
# 30
# Oslo
# Norway

# %% [markdown]
# The purpose of __init__() is to assign initial values to object properties

# %% [markdown]
# self, does not need to be named self

# %%
class Person:
  def __init__(myobject, name, age):
    myobject.name = name
    myobject.age = age

  def greet(abc):
    print("Hello, my name is " + abc.name)

p1 = Person("Emil", 36)
p1.greet()
# Out:
# Hello, my name is Emil

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        print(f"{self.year} {self.brand} {self.model}")

car1=Car("Toyota", "Corolla", 2020)
car1.display_info()
# Out:
# 2020 Toyota Corolla

# %%
class Person:
  def __init__(self, name):
    self.name = name

  def greet(self):
    return "Hello, " + self.name

  def welcome(self):
    message = self.greet()
    print(message + "! Welcome to our website.")

p1 = Person("Tobias")
p1.welcome()
# Out:
# Hello, Tobias! Welcome to our website.

# %% [markdown]
# What does the self parameter represent in a Python class?
#
# A reference to the current instance of the class

# %% [markdown]
# self must be the first parameter in Python instance methods because Python automatically passes the instance (object) as the first argument when you call a method on it.
#
# When you write hexagon.produces_resource(7), Python secretly translates it to Hexagon.produces_resource(hexagon, 7). The hexagon object itself becomes the first argument, so your method definition must accept it first: def produces_resource(self, roll):. This explicit passing follows Python's "explicit is better than implicit" philosophy.

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
p1 = Person("Tobias", 25)
print(p1.age)

p1.age = 26

print(p1.age)
# Out:
# 25
# 26

# %%
class Person:
    species = "Human" # Class property

    def __init__(self,name): # Instance property
        self.name = name


p1 = Person("Emil")
p2 = Person("Tobias")

print(p1.species)
print(p2.species)
# Out:
# Human
# Human

# %%
class Person:
    lastname = ""

    def __init__(self, name):
        self.name = name


p1 = Person("André")
p2 = Person("Emil")

Person.lastname = "sup"

print(p1.lastname)
print(p2.lastname)
# Out:
# sup
# sup

# %%
class Person:
    def __init__(self,name):
        self.name = name

p1 = Person("André") # creates the object

p1.age = 25
p1.city = "Oslo"

print(p1.name)
print(p1.age)
print(p1.city)
# Out:
# André
# 25
# Oslo

# %%
class Person:
    def __init__(self,name):
        self.name = name
    
    def greet(self):
        print("Hello " + self.name)

person_example = Person("André")
print(person_example.name)
person_example.greet()
# Out:
# André
# Hello André

# %% [markdown]
# Note: All methods must have self as the first parameter.

# %%
class Calculator:
    def add(self,a,b):
        return a+b
    def multiply(self,a,b):
        return a * b
    
calc = Calculator()
print(calc.add(5, 3))
print(calc.multiply(4, 7))
# Out:
# 8
# 28

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def celebrate_birthday(self):
    self.age += 1
    print(f"Happy birthday! You are now {self.age}")

p1 = Person("Linus", 25)
p1.celebrate_birthday()
p1.celebrate_birthday()
# Out:
# Happy birthday! You are now 26
# Happy birthday! You are now 27

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Emil", 36)
print(p1)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name} ({self.age})"

p1 = Person("Tobias", 36)
print(p1)
# Out:
# Tobias (36)

# %%
class Playlist:
  def __init__(self, name):
    self.name = name
    self.songs = []

  def add_song(self, song):
    self.songs.append(song)
    print(f"Added: {song}")

  def remove_song(self, song):
    if song in self.songs:
      self.songs.remove(song)
      print(f"Removed: {song}")

  def show_songs(self):
    print(f"Playlist '{self.name}':")
    for song in self.songs:
      print(f"- {song}")

my_playlist = Playlist("Favorites")
my_playlist.add_song("Bohemian Rhapsody")
my_playlist.add_song("Stairway to Heaven")
my_playlist.show_songs()
# Out:
# Added: Bohemian Rhapsody
# Added: Stairway to Heaven
# Playlist 'Favorites':
# - Bohemian Rhapsody
# - Stairway to Heaven

# %%
class Person:
  def __init__(self, name):
    self.name = name

  def greet(self):
    print("Hello!")

p1 = Person("Emil")

del Person.greet

p1.greet() # This will cause an error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 12
#       8 p1 = Person("Emil")
#      10 del Person.greet
# ---> 12 p1.greet() # This will cause an error
#
# AttributeError: 'Person' object has no attribute 'greet'

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()

class Student(Person):
  def __init__(self, fname, lname):
    Person.__init__(self, fname, lname)

x = Student("Mike", "Olsen")
x.printname()
# Out:
# John Doe
# Mike Olsen

# %% [markdown]
# When you add the __init__() function, the child class will no longer inherit the parent's __init__() function.

# %% [markdown]
# To keep the inheritance of the parent's __init__() function, add a call to the parent's __init__() function:

# %%
class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
    self.graduationyear = 2019

p1 = Student

print(p1.graduationyear)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 8
#       4     self.graduationyear = 2019
#       6 p1 = Student
# ----> 8 print(p1.graduationyear)
#
# AttributeError: type object 'Student' has no attribute 'graduationyear'

# %% [markdown]
# By using the super() function, you do not have to use the name of the parent element, it will automatically inherit the methods and properties from its parent.

# %% [markdown]
# Instead of this:
#
# class Student(Person):
#
#   def __init__(self, fname, lname):
#
#     Person.__init__(self, fname, lname)

# %%
class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

  def welcome(self):
    print("Welcome", self.firstname, self.lastname, "to the class of", self.graduationyear)

x = Student("Mike", "Olsen", 2019)
x.welcome()
# Out:
# Welcome Mike Olsen to the class of 2019

# %%
x = "Hello World!"

print(len(x))
# Out:
# 12

# %%
mytuple = ("apple", "banana", "cherry")

print(len(mytuple))
# Out:
# 3

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(len(thisdict))
# Out:
# 3

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
class Vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Move!")

class Car(Vehicle):
  pass

class Boat(Vehicle):
  def move(self):
    print("Sail!")

class Plane(Vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  print(x.brand)
  print(x.model)
  x.move()
# Out:
# Ford
# Mustang
# Move!
# Ibiza
# Touring 20
# Sail!
# Boeing
# 747
# Fly!

# %% [markdown]
# Child classes inherits the properties and methods from the parent class.

# %% [markdown]
# In the example above you can see that the Car class is empty, but it inherits brand, model, and move() from Vehicle.
#
# The Boat and Plane classes also inherit brand, model, and move() from Vehicle, but they both override the move() method.
#
# Because of polymorphism we can execute the same method for all classes.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age # Private property

p1 = Person("Emil", 25)
print(p1.name)
print(p1.__age) # This will cause an error
# Out:
# Emil
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 8
#       6 p1 = Person("Emil", 25)
#       7 print(p1.name)
# ----> 8 print(p1.__age) # This will cause an error
#
# AttributeError: 'Person' object has no attribute '__age'

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self):
    return self.__age

p1 = Person("Tobias", 25)
print(p1.get_age())
# Out:
# 25

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self): #getter getter method:
    return self.__age

  def set_age(self, age):
    if age > 0:
      self.__age = age
    else:
      print("Age must be positive")

p1 = Person("Tobias", 25)
print(p1.get_age())

p1.set_age(26)
print(p1.get_age())
# Out:
# 25
# 26

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self):
    return self.__age

  def set_age(self, age):
    if age > 0:
      self.__age = age
    else:
      print("Age must be positive")

p1 = Person("Tobias", 25)
print(p1.get_age())

p1.set_age(26)
print(p1.get_age())
# Out:
# 25
# 26

# %%
class Student:
  def __init__(self, name):
    self.name = name
    self.__grade = 0

  def set_grade(self, grade):
    if 0 <= grade <= 100:
      self.__grade = grade
    else:
      print("Grade must be between 0 and 100")

  def get_grade(self):
    return self.__grade

  def get_status(self):
    if self.__grade >= 60:
      return "Passed"
    else:
      return "Failed"

student = Student("Emil")
student.set_grade(85)
print(student.get_grade())
print(student.get_status())
# Out:
# 85
# Passed

# %%
class Person:
  def __init__(self, name, salary):
    self.name = name
    self._salary = salary # Protected property

p1 = Person("Linus", 50000)
print(p1.name)
print(p1._salary) # Can access, but shouldn't
# Out:
# Linus
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 8
#       6 p1 = Person("Linus", 50000)
#       7 print(p1.name)
# ----> 8 print(p1.__salary) # Can access, but shouldn't
#
# AttributeError: 'Person' object has no attribute '__salary'

# %% [markdown]
# Python uses naming conventions rather than strict access controls for class attributes, distinguishing "protected" (single underscore _) from "private" (double underscore __) properties.

# %%
class Calculator:
  def __init__(self):
    self.result = 0

  def __validate(self, num):
    if not isinstance(num, (int, float)):
      return False
    return True

  def add(self, num):
    if self.__validate(num):
      self.result += num
    else:
      print("Invalid number")

calc = Calculator()
calc.add(10)
calc.add(5)
print(calc.result)
# calc.__validate(5) # This would cause an error
# Out:
# 15

# %% [markdown]
# Note: Just like private properties with double underscores, private methods cannot be called directly from outside the class. The __validate method can only be used by other methods inside the class.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

p1 = Person("Emil", 30)

# This is how Python mangles the name:
print(p1._Person__age) # Not recommended!
# Out:
# 30

# %%
class Outer:
  def __init__(self):
    self.name = "Outer"

  class Inner:
    def __init__(self):
      self.name = "Inner"

    def display(self):
      print("Hello from inner class")

outer = Outer()
inner = outer.Inner()
inner.display()
# Out:
# Hello from inner class

# %%
class Outer:
  def __init__(self):
    self.name = "Emil"

  class Inner:
    def __init__(self, outer):
      self.outer = outer

    def display(self):
      print(f"Outer class name: {self.outer.name}")

outer = Outer()
inner = outer.Inner(outer)
inner.display()
# Out:
# Outer class name: Emil

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model
    self.engine = self.Engine()

  class Engine:
    def __init__(self):
      self.status = "Off"

    def start(self):
      self.status = "Running"
      print("Engine started")

    def stop(self):
      self.status = "Off"
      print("Engine stopped")

  def drive(self):
    if self.engine.status == "Running":
      print(f"Driving the {self.brand} {self.model}")
    else:
      print("Start the engine first!")

car = Car("Toyota", "Corolla")
car.drive()
car.engine.start()
car.drive()
# Out:
# Start the engine first!
# Engine started
# Driving the Toyota Corolla

# %%
class Computer:
  def __init__(self):
    self.cpu = self.CPU()
    self.ram = self.RAM()

  class CPU:
    def process(self):
      print("Processing data...")

  class RAM:
    def store(self):
      print("Storing data...")

computer = Computer()
computer.cpu.process()
computer.ram.store()
# Out:
# Processing data...
# Storing data...
